# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
f1=np.loadtxt('f1.dat')
f2=np.loadtxt('f2.dat')
f3=np.loadtxt('f3.dat')
f4=np.loadtxt('f4.dat')

# %%
plt.figure(figsize=(7,6))
plt.ylim(bottom=0,top=350000)
plt.plot(f1,label='r=1.8')
plt.plot(f2,label='r=3')
plt.plot(f3,label='r=5')
plt.plot(f4,label='r=7')
plt.legend(fontsize=15)
plt.xlabel('number of added edges to graph');plt.ylabel('fixation time')
# Out:
# Text(0, 0.5, 'fixation time')

# %%
plt.figure(figsize=(7,6))
plt.ylim(bottom=0,top=75000)
plt.plot(f1,label='r=1.8')
plt.plot(f2,label='r=3')
plt.plot(f3,label='r=5')
plt.plot(f4,label='r=7')
plt.legend(fontsize=15)
plt.xlabel('number of added edges to graph');plt.ylabel('fixation time')
# Out:
# Text(0, 0.5, 'fixation time')

# %%
plt.figure(figsize=(7,6))

#plt.loglog(f1,label='r=1.8')

plt.loglog(f2,label='r=3','y')
#plt.loglog(f3,label='r=5')
#plt.loglog(f4,label='r=7')
plt.legend(fontsize=15)
plt.xlabel('Log number of added edges to graph');plt.ylabel('Log fixation time')
# Out:
#   Input In [16]
#     plt.loglog(f2,label='r=3','y')
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
plt.figure(figsize=(7,6))
#plt.ylim(bottom=0,top=75000)
plt.loglog(f1,label='r=1.8')
plt.loglog(f2,label='r=3')
plt.loglog(f3,label='r=5')
plt.loglog(f4,label='r=7')
plt.legend(fontsize=15)
plt.xlabel('Log number of added edges to graph');plt.ylabel('Log fixation time')
# Out:
# Text(0, 0.5, 'Log fixation time')

# %%
f8=np.loadtxt('f5.dat')
f7=np.loadtxt('f6.dat')
f6=np.loadtxt('f7.dat')
f5=np.loadtxt('f8.dat')

# %%
plt.figure(figsize=(8,4))
#plt.ylim(bottom=0,top=75000)
#plt.loglog(f1,label='r=1.8')
#plt.loglog(f2,label='r=3',color='orange')
#plt.loglog(f3,label='r=5',color='green')
plt.loglog(f4,label='r=7',color='red')
plt.legend(fontsize=15)
plt.xlabel('Log number of added edges to graph');plt.ylabel('Log fixation time')
# Out:
# Text(0, 0.5, 'Log fixation time')

# %%
plt.figure(figsize=(10,5))
plt.ylim(bottom=0,top=1)
plt.plot(f5,label='r=1.8')
plt.plot(f6,label='r=3')
plt.plot(f7,label='r=5')
plt.plot(f8,label='r=7')
plt.legend(fontsize=15)
plt.xlabel('number of added edges to graph');plt.ylabel('fixation probability')
# Out:
# Text(0, 0.5, 'fixation probability')

# %%
f10=np.loadtxt('f10.dat')

# %%
plt.figure(figsize=(10,5))
plt.ylim(bottom=0,top=1)
plt.plot(f6,label='random_tree r=3')
plt.plot(f10,label='star r=3',alpha=0.6)

plt.legend(fontsize=15)
plt.xlabel('number of added edges to graph');plt.ylabel('fixation probability')
# Out:
# Text(0, 0.5, 'fixation probability')
